# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_lob = pd.read_csv("PXA.X 20250115 Market Depth Legacy x 10 Raw.csv")
raw_lob.head(10)
# Out:
# /var/folders/_w/_65ls85d0k16yc1syq58zb3h0000gn/T/ipykernel_81137/407212587.py:1: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_lob = pd.read_csv("PXA.X 20250115 Market Depth Legacy x 10 Raw.csv")
#      #RIC        Domain                         Date-Time            Type  \
# 0  PXA.AX  Market Price  2025-01-15T05:09:04.740834340+11  Normalized LL2
# 1  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 2  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 3  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 4  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 5  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 6  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 7  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 8  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 9  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
#
#    L1-BidPrice  L1-BidSize  L1-BuyNo  L1-AskPrice  L1-AskSize  L1-SellNo  ...  \
# 0          NaN         NaN       NaN          NaN         NaN        NaN  ...
# 1        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 2        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 3        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 4        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 5        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 6        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 7        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 8        12.68      2208.0       1.0          NaN         NaN        NaN  ...
# 9        12.68      2208.0       1.0          NaN         NaN        NaN  ...
#
#    L9-AskPrice  L9-AskSize  L9-SellNo  L10-BidPrice  L10-BidSize  L10-BuyNo  \
# 0          NaN         NaN        NaN           NaN          NaN        NaN
# 1          NaN         NaN        NaN           NaN          NaN        NaN
# 2          NaN         NaN        NaN           NaN          NaN        NaN
# 3          NaN         NaN        NaN           NaN          NaN        NaN
# 4          NaN         NaN        NaN           NaN          NaN        NaN
# 5          NaN         NaN        NaN           NaN          NaN        NaN
# 6          NaN         NaN        NaN           NaN          NaN        NaN
# 7          NaN         NaN        NaN           NaN          NaN        NaN
# 8          NaN         NaN        NaN           NaN          NaN        NaN
# 9          NaN         NaN        NaN           NaN          NaN        NaN
#
#    L10-AskPrice  L10-AskSize  L10-SellNo  Exch Time
# 0           NaN          NaN         NaN        NaN
# 1           NaN          NaN         NaN        NaN
# 2           NaN          NaN         NaN        NaN
# 3           NaN          NaN         NaN        NaN
# 4           NaN          NaN         NaN        NaN
# 5           NaN          NaN         NaN        NaN
# 6           NaN          NaN         NaN        NaN
# 7           NaN          NaN         NaN        NaN
# 8           NaN          NaN         NaN        NaN
# 9           NaN          NaN         NaN        NaN
#
# [10 rows x 65 columns]

# %%
lob = pd.read_csv("PXA.X 20250115 Market Depth Legacy x 10.csv")
lob.head(10)
# Out:
# /var/folders/_w/_65ls85d0k16yc1syq58zb3h0000gn/T/ipykernel_81137/1136314841.py:1: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   lob = pd.read_csv("PXA.X 20250115 Market Depth Legacy x 10.csv")
#      #RIC        Domain                         Date-Time            Type  \
# 0  PXA.AX  Market Price  2025-01-15T05:09:04.740834340+11  Normalized LL2
# 1  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 2  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 3  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 4  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 5  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 6  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 7  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 8  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
# 9  PXA.AX  Market Price  2025-01-15T06:10:12.205772364+11  Normalized LL2
#
#    L1-BidPrice  L2-BidPrice  L3-BidPrice  L4-BidPrice  L5-BidPrice  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1        12.68          NaN          NaN          NaN          NaN
# 2        12.68         12.6          NaN          NaN          NaN
# 3        12.68         12.6          NaN          NaN          NaN
# 4        12.68         12.6        12.56          NaN          NaN
# 5        12.68         12.6        12.56         12.5          NaN
# 6        12.68         12.6        12.56         12.5          NaN
# 7        12.68         12.6        12.56         12.5          NaN
# 8        12.68         12.6        12.56         12.5          NaN
# 9        12.68         12.6        12.56         12.5          NaN
#
#    L6-BidPrice  ...  L2-SellNo  L3-SellNo  L4-SellNo  L5-SellNo  L6-SellNo  \
# 0          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 1          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 2          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 3          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 4          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 5          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 6          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 7          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 8          NaN  ...        NaN        NaN        NaN        NaN        NaN
# 9          NaN  ...        NaN        NaN        NaN        NaN        NaN
#
#    L7-SellNo  L8-SellNo  L9-SellNo  L10-SellNo  Exch Time
# 0        NaN        NaN        NaN         NaN        NaN
# 1        NaN        NaN        NaN         NaN        NaN
# 2        NaN        NaN        NaN         NaN        NaN
# 3        NaN        NaN        NaN         NaN        NaN
# 4        NaN        NaN        NaN         NaN        NaN
# 5        NaN        NaN        NaN         NaN        NaN
# 6        NaN        NaN        NaN         NaN        NaN
# 7        NaN        NaN        NaN         NaN        NaN
# 8        NaN        NaN        NaN         NaN        NaN
# 9        NaN        NaN        NaN         NaN        NaN
#
# [10 rows x 65 columns]

# %%
trades = pd.read_csv("PXA.X 20250115 Stocks Trades.csv")
trades.head(10)
# Out:
#       #RIC  Alias Underlying RIC        Domain  \
# 0  PXA.CHA                   NaN  Market Price
# 1  PXA.CHA                   NaN  Market Price
# 2   PXA.AX                   NaN  Market Price
# 3   PXA.AX                   NaN  Market Price
# 4  PXA.CHA                   NaN  Market Price
# 5   PXA.AX                   NaN  Market Price
# 6   PXA.AX                   NaN  Market Price
# 7   PXA.AX                   NaN  Market Price
# 8   PXA.AX                   NaN  Market Price
# 9   PXA.AX                   NaN  Market Price
#
#                           Date-Time            Type  Price  Volume  \
# 0  2025-01-15T05:00:00.975146674+11  Mkt. Condition    NaN     NaN
# 1  2025-01-15T06:35:00.160002491+11  Mkt. Condition    NaN     NaN
# 2  2025-01-15T07:00:03.041111959+11  Mkt. Condition    NaN     NaN
# 3  2025-01-15T08:38:08.550466187+11  Mkt. Condition    NaN     NaN
# 4  2025-01-15T10:00:00.129028651+11  Mkt. Condition    NaN     NaN
# 5  2025-01-15T10:06:52.140473262+11  Mkt. Condition    NaN     NaN
# 6  2025-01-15T10:06:52.309881969+11           Trade  12.74   111.0
# 7  2025-01-15T10:06:52.309985725+11           Trade  12.74    10.0
# 8  2025-01-15T10:06:52.309985725+11           Trade  12.74     1.0
# 9  2025-01-15T10:06:52.309985725+11           Trade  12.74     8.0
#
#    Market VWAP  Buyer ID  Bid Price  ...  Ask Price  Ask Size  \
# 0          NaN       NaN        NaN  ...        NaN       NaN
# 1          NaN       NaN        NaN  ...        NaN       NaN
# 2          NaN       NaN        NaN  ...        NaN       NaN
# 3          NaN       NaN        NaN  ...        NaN       NaN
# 4          NaN       NaN        NaN  ...        NaN       NaN
# 5          NaN       NaN        NaN  ...        NaN       NaN
# 6        12.74       NaN      12.68  ...      12.74     171.0
# 7        12.74       NaN      12.68  ...      12.74     171.0
# 8        12.74       NaN      12.68  ...      12.74     171.0
# 9        12.74       NaN      12.68  ...      12.74     171.0
#
#                                      Qualifiers           Exch Time  \
# 0  C[PERIOD_CD2];CLS[PRC_QL_CD];C  [INST_PHASE]                 NaN
# 1  A[PERIOD_CD2];   [PRC_QL_CD];PET[INST_PHASE]                 NaN
# 2                                POP[PRC_QL_CD]                 NaN
# 3                                  ND [PRC_QL2]                 NaN
# 4  T[PERIOD_CD2];   [PRC_QL_CD];T  [INST_PHASE]                 NaN
# 5                                OPN[PRC_QL_CD]                 NaN
# 6       [ACT_FLAG1];MO[GV4_TEXT];MO[LSTSALCOND]  23:06:52.002000000
# 7       [ACT_FLAG1];MO[GV4_TEXT];MO[LSTSALCOND]  23:06:52.002000000
# 8       [ACT_FLAG1];MO[GV4_TEXT];MO[LSTSALCOND]  23:06:52.002000000
# 9       [ACT_FLAG1];MO[GV4_TEXT];MO[LSTSALCOND]  23:06:52.002000000
#
#          Date Tick Dir.   Open   High    Low  Turnover
# 0         NaN       NaN    NaN    NaN    NaN       NaN
# 1         NaN       NaN    NaN    NaN    NaN       NaN
# 2         NaN       NaN    NaN    NaN    NaN       NaN
# 3         NaN       NaN    NaN    NaN    NaN       NaN
# 4         NaN       NaN    NaN    NaN    NaN       NaN
# 5         NaN       NaN    NaN    NaN    NaN       NaN
# 6  2025-01-14         v  12.74  12.74  12.74   1414.14
# 7  2025-01-14         v  12.74  12.74  12.74   1541.54
# 8  2025-01-14         v  12.74  12.74  12.74   1554.28
# 9  2025-01-14         v  12.74  12.74  12.74   1656.20
#
# [10 rows x 22 columns]
